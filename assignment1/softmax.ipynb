# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/softmax.py**.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.391526
# sanity check: 2.302585

# %% [markdown]
# ## Inline Question 1:
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# **Your answer:** *Assume even probability distribution among classes, thus $loss = \frac{1}{N}\sum(-\log(0.1))=-\log(0.1)$*

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: 0.687012 analytic: 0.687012, relative error: 1.064216e-07
# numerical: 1.278117 analytic: 1.278117, relative error: 3.731117e-08
# numerical: 1.938557 analytic: 1.938557, relative error: 1.490009e-08
# numerical: -0.342687 analytic: -0.342687, relative error: 9.014288e-09
# numerical: 0.965480 analytic: 0.965480, relative error: 2.241057e-08
# numerical: -0.349657 analytic: -0.349657, relative error: 1.163632e-07
# numerical: 0.383214 analytic: 0.383214, relative error: 2.139413e-07
# numerical: -2.052761 analytic: -2.052761, relative error: 1.357018e-08
# numerical: 0.265823 analytic: 0.265823, relative error: 6.627520e-08
# numerical: -2.785703 analytic: -2.785703, relative error: 8.611442e-09
# numerical: -4.115838 analytic: -4.115838, relative error: 1.064638e-08
# numerical: -1.098930 analytic: -1.098930, relative error: 5.866327e-09
# numerical: -5.343657 analytic: -5.343658, relative error: 1.420474e-08
# numerical: -2.676147 analytic: -2.676147, relative error: 1.801131e-08
# numerical: 1.335779 analytic: 1.335779, relative error: 1.408753e-08
# numerical: -3.950195 analytic: -3.950195, relative error: 1.022796e-08
# numerical: -1.728436 analytic: -1.728436, relative error: 1.505567e-10
# numerical: -0.765744 analytic: -0.765744, relative error: 2.606973e-08
# numerical: 1.168078 analytic: 1.168078, relative error: 1.385565e-08
# numerical: -0.886357 analytic: -0.886357, relative error: 9.558800e-09

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.391526e+00 computed in 0.127773s
# vectorized loss: 2.391526e+00 computed in 0.008758s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None
learning_rates = np.linspace(1e-7, 5e-7, 10)
regularization_strengths = np.logspace(3, np.log10(5)+4, 10)

################################################################################
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################
num_iters = 2000
import itertools
for lr, reg in itertools.product(learning_rates, regularization_strengths):
    softmax = Softmax()
    softmax.train(X_train, y_train, learning_rate=lr, reg=reg, num_iters=num_iters)
    y_train_pred = softmax.predict(X_train)
    acc_train = np.mean(y_train == y_train_pred)
    y_val_pred = softmax.predict(X_val)
    acc_val = np.mean(y_val == y_val_pred)
    results[(lr, reg)] = (acc_train, acc_val)
    if best_val < acc_val:
        best_val, best_softmax = acc_val, softmax    


# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# lr 1.000000e-07 reg 1.000000e+03 train accuracy: 0.273571 val accuracy: 0.284000
# lr 1.000000e-07 reg 1.544452e+03 train accuracy: 0.276082 val accuracy: 0.267000
# lr 1.000000e-07 reg 2.385332e+03 train accuracy: 0.282020 val accuracy: 0.284000
# lr 1.000000e-07 reg 3.684031e+03 train accuracy: 0.307571 val accuracy: 0.312000
# lr 1.000000e-07 reg 5.689810e+03 train accuracy: 0.335347 val accuracy: 0.338000
# lr 1.000000e-07 reg 8.787639e+03 train accuracy: 0.354490 val accuracy: 0.375000
# lr 1.000000e-07 reg 1.357209e+04 train accuracy: 0.364204 val accuracy: 0.376000
# lr 1.000000e-07 reg 2.096144e+04 train accuracy: 0.359224 val accuracy: 0.368000
# lr 1.000000e-07 reg 3.237394e+04 train accuracy: 0.346327 val accuracy: 0.366000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.325694 val accuracy: 0.344000
# lr 1.444444e-07 reg 1.000000e+03 train accuracy: 0.296347 val accuracy: 0.303000
# lr 1.444444e-07 reg 1.544452e+03 train accuracy: 0.302041 val accuracy: 0.313000
# lr 1.444444e-07 reg 2.385332e+03 train accuracy: 0.320980 val accuracy: 0.328000
# lr 1.444444e-07 reg 3.684031e+03 train accuracy: 0.339694 val accuracy: 0.329000
# lr 1.444444e-07 reg 5.689810e+03 train accuracy: 0.360224 val accuracy: 0.360000
# lr 1.444444e-07 reg 8.787639e+03 train accuracy: 0.372204 val accuracy: 0.389000
# lr 1.444444e-07 reg 1.357209e+04 train accuracy: 0.367653 val accuracy: 0.389000
# lr 1.444444e-07 reg 2.096144e+04 train accuracy: 0.358041 val accuracy: 0.377000
# lr 1.444444e-07 reg 3.237394e+04 train accuracy: 0.341918 val accuracy: 0.357000
# lr 1.444444e-07 reg 5.000000e+04 train accuracy: 0.330163 val accuracy: 0.344000
# lr 1.888889e-07 reg 1.000000e+03 train accuracy: 0.312224 val accuracy: 0.315000
# lr 1.888889e-07 reg 1.544452e+03 train accuracy: 0.323000 val accuracy: 0.323000
# lr 1.888889e-07 reg 2.385332e+03 train accuracy: 0.347102 val accuracy: 0.333000
# lr 1.888889e-07 reg 3.684031e+03 train accuracy: 0.367061 val accuracy: 0.368000
# lr 1.888889e-07 reg 5.689810e+03 train accuracy: 0.377959 val accuracy: 0.391000
# lr 1.888889e-07 reg 8.787639e+03 train accuracy: 0.376469 val accuracy: 0.382000
# lr 1.888889e-07 reg 1.357209e+04 train accuracy: 0.364551 val accuracy: 0.385000
# lr 1.888889e-07 reg 2.096144e+04 train accuracy: 0.354694 val accuracy: 0.372000
# lr 1.888889e-07 reg 3.237394e+04 train accuracy: 0.340429 val accuracy: 0.355000
# lr 1.888889e-07 reg 5.000000e+04 train accuracy: 0.323367 val accuracy: 0.334000
# lr 2.333333e-07 reg 1.000000e+03 train accuracy: 0.335061 val accuracy: 0.333000
# lr 2.333333e-07 reg 1.544452e+03 train accuracy: 0.342633 val accuracy: 0.341000
# lr 2.333333e-07 reg 2.385332e+03 train accuracy: 0.363939 val accuracy: 0.385000
# lr 2.333333e-07 reg 3.684031e+03 train accuracy: 0.379959 val accuracy: 0.384000
# lr 2.333333e-07 reg 5.689810e+03 train accuracy: 0.381286 val accuracy: 0.398000
# lr 2.333333e-07 reg 8.787639e+03 train accuracy: 0.376673 val accuracy: 0.396000
# lr 2.333333e-07 reg 1.357209e+04 train accuracy: 0.364531 val accuracy: 0.374000
# lr 2.333333e-07 reg 2.096144e+04 train accuracy: 0.360265 val accuracy: 0.380000
# lr 2.333333e-07 reg 3.237394e+04 train accuracy: 0.343041 val accuracy: 0.355000
# lr 2.333333e-07 reg 5.000000e+04 train accuracy: 0.322633 val accuracy: 0.347000
# lr 2.777778e-07 reg 1.000000e+03 train accuracy: 0.342939 val accuracy: 0.351000
# lr 2.777778e-07 reg 1.544452e+03 train accuracy: 0.358000 val accuracy: 0.347000
# lr 2.777778e-07 reg 2.385332e+03 train accuracy: 0.375449 val accuracy: 0.393000
# lr 2.777778e-07 reg 3.684031e+03 train accuracy: 0.387571 val accuracy: 0.400000
# lr 2.777778e-07 reg 5.689810e+03 train accuracy: 0.385000 val accuracy: 0.400000
# lr 2.777778e-07 reg 8.787639e+03 train accuracy: 0.375796 val accuracy: 0.387000
# lr 2.777778e-07 reg 1.357209e+04 train accuracy: 0.366367 val accuracy: 0.374000
# lr 2.777778e-07 reg 2.096144e+04 train accuracy: 0.354735 val accuracy: 0.354000
# lr 2.777778e-07 reg 3.237394e+04 train accuracy: 0.339388 val accuracy: 0.349000
# lr 2.777778e-07 reg 5.000000e+04 train accuracy: 0.330143 val accuracy: 0.345000
# lr 3.222222e-07 reg 1.000000e+03 train accuracy: 0.352939 val accuracy: 0.351000
# lr 3.222222e-07 reg 1.544452e+03 train accuracy: 0.373857 val accuracy: 0.383000
# lr 3.222222e-07 reg 2.385332e+03 train accuracy: 0.385408 val accuracy: 0.378000
# lr 3.222222e-07 reg 3.684031e+03 train accuracy: 0.388980 val accuracy: 0.393000
# lr 3.222222e-07 reg 5.689810e+03 train accuracy: 0.384490 val accuracy: 0.393000
# lr 3.222222e-07 reg 8.787639e+03 train accuracy: 0.372041 val accuracy: 0.389000
# lr 3.222222e-07 reg 1.357209e+04 train accuracy: 0.368061 val accuracy: 0.391000
# lr 3.222222e-07 reg 2.096144e+04 train accuracy: 0.351571 val accuracy: 0.349000
# lr 3.222222e-07 reg 3.237394e+04 train accuracy: 0.343102 val accuracy: 0.358000
# lr 3.222222e-07 reg 5.000000e+04 train accuracy: 0.324837 val accuracy: 0.332000
# lr 3.666667e-07 reg 1.000000e+03 train accuracy: 0.367122 val accuracy: 0.373000
# lr 3.666667e-07 reg 1.544452e+03 train accuracy: 0.381531 val accuracy: 0.384000
# lr 3.666667e-07 reg 2.385332e+03 train accuracy: 0.390857 val accuracy: 0.387000
# lr 3.666667e-07 reg 3.684031e+03 train accuracy: 0.392286 val accuracy: 0.397000
# lr 3.666667e-07 reg 5.689810e+03 train accuracy: 0.388571 val accuracy: 0.405000
# lr 3.666667e-07 reg 8.787639e+03 train accuracy: 0.377184 val accuracy: 0.395000
# lr 3.666667e-07 reg 1.357209e+04 train accuracy: 0.365571 val accuracy: 0.378000
# lr 3.666667e-07 reg 2.096144e+04 train accuracy: 0.353041 val accuracy: 0.355000
# lr 3.666667e-07 reg 3.237394e+04 train accuracy: 0.336918 val accuracy: 0.340000
# lr 3.666667e-07 reg 5.000000e+04 train accuracy: 0.336694 val accuracy: 0.352000
# lr 4.111111e-07 reg 1.000000e+03 train accuracy: 0.373000 val accuracy: 0.376000
# lr 4.111111e-07 reg 1.544452e+03 train accuracy: 0.384898 val accuracy: 0.384000
# lr 4.111111e-07 reg 2.385332e+03 train accuracy: 0.392694 val accuracy: 0.384000
# lr 4.111111e-07 reg 3.684031e+03 train accuracy: 0.394571 val accuracy: 0.401000
# lr 4.111111e-07 reg 5.689810e+03 train accuracy: 0.386286 val accuracy: 0.393000
# lr 4.111111e-07 reg 8.787639e+03 train accuracy: 0.375918 val accuracy: 0.383000
# lr 4.111111e-07 reg 1.357209e+04 train accuracy: 0.370857 val accuracy: 0.379000
# lr 4.111111e-07 reg 2.096144e+04 train accuracy: 0.346776 val accuracy: 0.357000
# lr 4.111111e-07 reg 3.237394e+04 train accuracy: 0.341857 val accuracy: 0.350000
# lr 4.111111e-07 reg 5.000000e+04 train accuracy: 0.312918 val accuracy: 0.327000
# lr 4.555556e-07 reg 1.000000e+03 train accuracy: 0.382041 val accuracy: 0.395000
# lr 4.555556e-07 reg 1.544452e+03 train accuracy: 0.396490 val accuracy: 0.406000
# lr 4.555556e-07 reg 2.385332e+03 train accuracy: 0.398408 val accuracy: 0.401000
# lr 4.555556e-07 reg 3.684031e+03 train accuracy: 0.393796 val accuracy: 0.396000
# lr 4.555556e-07 reg 5.689810e+03 train accuracy: 0.385551 val accuracy: 0.402000
# lr 4.555556e-07 reg 8.787639e+03 train accuracy: 0.370653 val accuracy: 0.383000
# lr 4.555556e-07 reg 1.357209e+04 train accuracy: 0.365102 val accuracy: 0.368000
# lr 4.555556e-07 reg 2.096144e+04 train accuracy: 0.346224 val accuracy: 0.360000
# lr 4.555556e-07 reg 3.237394e+04 train accuracy: 0.343898 val accuracy: 0.359000
# lr 4.555556e-07 reg 5.000000e+04 train accuracy: 0.327347 val accuracy: 0.347000
# lr 5.000000e-07 reg 1.000000e+03 train accuracy: 0.386082 val accuracy: 0.389000
# lr 5.000000e-07 reg 1.544452e+03 train accuracy: 0.397612 val accuracy: 0.396000
# lr 5.000000e-07 reg 2.385332e+03 train accuracy: 0.397592 val accuracy: 0.414000
# lr 5.000000e-07 reg 3.684031e+03 train accuracy: 0.394061 val accuracy: 0.396000
# lr 5.000000e-07 reg 5.689810e+03 train accuracy: 0.382898 val accuracy: 0.393000
# lr 5.000000e-07 reg 8.787639e+03 train accuracy: 0.370224 val accuracy: 0.388000
# lr 5.000000e-07 reg 1.357209e+04 train accuracy: 0.360918 val accuracy: 0.375000
# lr 5.000000e-07 reg 2.096144e+04 train accuracy: 0.352224 val accuracy: 0.374000
# lr 5.000000e-07 reg 3.237394e+04 train accuracy: 0.332469 val accuracy: 0.353000
# lr 5.000000e-07 reg 5.000000e+04 train accuracy: 0.323306 val accuracy: 0.347000
# best validation accuracy achieved during cross-validation: 0.414000

# %%
# Visualize the cross-validation results
import math
x_scatter = [x[0] for x in results]
y_scatter = [math.log10(x[1]) for x in results]

# plot training accuracy
marker_size = 100
colors = [results[x][0] for x in results]
plt.subplot(2, 1, 1)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors)
plt.colorbar()
plt.xlim([0.9e-7,5.1e-7])
plt.xlabel('learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 training accuracy')

# plot validation accuracy
colors = [results[x][1] for x in results] # default size of markers is 20
plt.subplot(2, 1, 2)
plt.scatter(x_scatter, y_scatter, marker_size, c=colors)
plt.colorbar()
plt.xlim([0.9e-7,5.1e-7])
plt.xlabel('learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 validation accuracy')
plt.tight_layout()
plt.show()

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.393000

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])

# %% [markdown]
# Although the resolution is low, the results obtained are quite similar to svm prediction.
