# %% [markdown]
# This notebook applies tensorflow to build a deep CNN to classify images on cifar-10.

# %%
import os
import time
from datetime import timedelta
from layers_tf import *
from utils import show_graph

# %% [markdown]
# Invoke the above function to get our data.

# %%
X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()
print('Train data shape:\t\t', X_train.shape)
print('Train labels shape:\t\t', y_train.shape)
print('Validation data shape:\t\t', X_val.shape)
print('Validation labels shape:\t', y_val.shape)
print('Test data shape:\t\t', X_test.shape)
print('Test labels shape:\t\t', y_test.shape)
# Out:
# Train data shape:		 (45000, 32, 32, 3)
# Train labels shape:		 (45000,)
# Validation data shape:		 (5000, 32, 32, 3)
# Validation labels shape:	 (5000,)
# Test data shape:		 (10000, 32, 32, 3)
# Test labels shape:		 (10000,)

# %% [markdown]
# Input data (images) dimensions.

# %%
img_size = 32
img_size_flat = img_size * img_size
img_shape = (img_size, img_size)
num_channels = 3
num_classes = 10

# %% [markdown]
# configuration of cnn architecture.

# %%
filter_size1, num_filters1 = 3, 16
filter_size2, num_filters2 = 3, 32
filter_size3, num_filters3 = 3, 64
filter_size4, num_filters4 = 3, 128
fc_size1, fc_size2 = 256, 256
print_every = 1000

# %% [markdown]
# ### Start to build tensorflow compuatation graph
#
# clear old variables.

# %%
tf.reset_default_graph()

# %% [markdown]
# Define placeholder variables.

# %%
x_image = tf.placeholder(tf.float32, [None, 32, 32, 3], name='x_image')
y_true_cls = tf.placeholder(tf.int64, [None], name='y_true_cls')
phase = tf.placeholder(tf.bool, name='phase')

# %% [markdown]
# Add initializer.

# %%
#init = tf.contrib.layers.xavier_initializer()
init = tf.contrib.layers.variance_scaling_initializer()

# %% [markdown]
# add regularizer.

# %%
reg = tf.contrib.layers.l1_regularizer(scale=5e-4)

# %% [markdown]
# add layers, within a unit of combinations of layers, a different variable scope is defined to avoid confusion of variables names.

# %%
conv1 = conv_norm_relu_pool(x_image, num_filters1, filter_size1, 2, phase, init, reg, 'conv1')
conv2 = conv_norm_relu_pool(conv1,   num_filters2, filter_size2, 2, phase, init, reg, 'conv2')
conv3 = conv_norm_relu_pool(conv2,   num_filters3, filter_size3, 2, phase, init, reg, 'conv3')
conv4 = conv_norm_relu_pool(conv3,   num_filters4, filter_size4, 2, phase, init, reg, 'conv4')
flat = tf.contrib.layers.flatten(conv4, scope='flat')
fc1 = dense_norm_relu(flat, fc_size1, phase, init, reg, 'fc1')
fc2 = dense_norm_relu(fc1,  fc_size2, phase, init, reg, 'fc2')
logits = tf.layers.dense(fc2, num_classes, kernel_initializer=init, kernel_regularizer=reg, name='logits')

# %% [markdown]
# define loss function.

# %%
with tf.name_scope('loss'):
    # predicted classes
    y_pred = tf.nn.softmax(logits)  # one-hot encoding
    y_pred_cls = tf.argmax(y_pred, dimension=1) # as class number

    # cost function to be optimized
    cross_entropy = tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=tf.one_hot(y_true_cls, 10))
    base_loss = tf.reduce_mean(cross_entropy)
    reg_loss = tf.get_collection(tf.GraphKeys.REGULARIZATION_LOSSES)
    loss = tf.add_n([base_loss] + reg_loss)

# %% [markdown]
# define accuracy measure.

# %%
with tf.name_scope('accuracy'):
    # performance measure
    correct_prediction = tf.equal(y_pred_cls, y_true_cls)
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# %% [markdown]
# implement learning_rate decay.

# %%
global_step = tf.Variable(initial_value=0, trainable=False)
learning_rate_init = 1e-3
decay_steps = 1000
learning_rate = tf.train.exponential_decay(learning_rate_init, global_step, decay_steps, 0.95, staircase=True)

# %% [markdown]
# batch normalization in tensorflow requires this extra dependency.

# %%
extra_update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
with tf.control_dependencies(extra_update_ops):
    optimizer = tf.train.AdamOptimizer(learning_rate).minimize(loss, global_step=global_step)

# %% [markdown]
# #### plot computational graphics

# %%
show_graph(tf.get_default_graph().as_graph_def())
# Out:
#         <iframe seamless style="width:1200px;height:620px;border:0" srcdoc="
#         <script>
#           function load() {
#             document.getElementById(&quot;graph0.8990508847205797&quot;).pbtxt = 'node {\n  name: &quot;x_image&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n      }\n    }\n  }\n}\nnode {\n  name: &quot;y_true_cls&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT64\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n      }\n    }\n  }\n}\nnode {\n  name: &quot;phase&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_BOOL\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n      }\n    }\n  }\n}\nnode {\n  name: &quot;conv1/conv/kernel/Initializer/random_uniform/shape&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@conv1/conv/kernel&quot;\n      }\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_INT32\n        tensor_shape {\n          dim {\n            size: 4\n          }\n        }\n        tensor_content: &quot;\\003\\000\\000\\000\\003\\000\\000\\000\\003\\000\\000\\000\\020\\000\\000\\000&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;conv1/conv/kernel/Initializer/random_uniform/min&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@conv1/conv/kernel&quot;\n      }\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n        }\n        float_val: -0.1873171627521515\n      }\n    }\n  }\n}\nnode {\n  name: &quot;conv1/conv/kernel/Initializer/random_uniform/max&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@conv1/conv/kernel&quot;\n      }\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n        }\n        float_val: 0.1873171627521515\n      }\n    }\n  }\n}\nnode {\n  name: &quot;conv1/conv/kernel/Initializer/random_uniform/RandomUniform&quot;\n  op: &quot;RandomUniform&quot;\n  input: &quot;conv1/conv/kernel/Initializer/random_uniform/shape&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@conv1/conv/kernel&quot;\n      }\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;seed&quot;\n    value {\n      i: 0\n    }\n  }\n  attr {\n    key: &quot;seed2&quot;\n    value {\n      i: 0\n    }\n  }\n}\nnode {\n  name: &quot;conv1/conv/kernel/Initializer/random_uniform/sub&quot;\n  op: &quot;Sub&quot;\n  input: &quot;conv1/conv/kernel/Initializer/random_uniform/max&quot;\n  input: &quot;conv1/conv/kernel/Initializer/random_uniform/min&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@conv1/conv/kernel&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;conv1/conv/kernel/Initializer/random_uniform/mul&quot;\n  op: &quot;Mul&quot;\n  input: &quot;conv1/conv/kernel/Initializer/random_uniform/RandomUniform&quot;\n  input: &quot;conv1/conv/kernel/Initializer/random_uniform/sub&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &q ...

# %% [markdown]
# #### print all global variables

# %%
[v.name for v in tf.global_variables()]
# Out:
# ['conv1/conv/kernel:0',
#  'conv1/conv/bias:0',
#  'conv1/bn/beta:0',
#  'conv1/bn/gamma:0',
#  'conv1/bn/moving_mean:0',
#  'conv1/bn/moving_variance:0',
#  'conv2/conv/kernel:0',
#  'conv2/conv/bias:0',
#  'conv2/bn/beta:0',
#  'conv2/bn/gamma:0',
#  'conv2/bn/moving_mean:0',
#  'conv2/bn/moving_variance:0',
#  'conv3/conv/kernel:0',
#  'conv3/conv/bias:0',
#  'conv3/bn/beta:0',
#  'conv3/bn/gamma:0',
#  'conv3/bn/moving_mean:0',
#  'conv3/bn/moving_variance:0',
#  'conv4/conv/kernel:0',
#  'conv4/conv/bias:0',
#  'conv4/bn/beta:0',
#  'conv4/bn/gamma:0',
#  'conv4/bn/moving_mean:0',
#  'conv4/bn/moving_variance:0',
#  'fc1/dense/kernel:0',
#  'fc1/dense/bias:0',
#  'fc1/bn/beta:0',
#  'fc1/bn/gamma:0',
#  'fc1/bn/moving_mean:0',
#  'fc1/bn/moving_variance:0',
#  'fc2/dense/kernel:0',
#  'fc2/dense/bias:0',
#  'fc2/bn/beta:0',
#  'fc2/bn/gamma:0',
#  'fc2/bn/moving_mean:0',
#  'fc2/bn/moving_variance:0',
#  'logits/kernel:0',
#  'logits/bias:0',
#  'Variable:0',
#  'beta1_power:0',
#  'beta2_power:0',
#  'conv1/conv/kernel/Adam:0',
#  'conv1/conv/kernel/Adam_1:0',
#  'conv1/conv/bias/Adam:0',
#  'conv1/conv/bias/Adam_1:0',
#  'conv1/bn/beta/Adam:0',
#  'conv1/bn/beta/Adam_1:0',
#  'conv1/bn/gamma/Adam:0',
#  'conv1/bn/gamma/Adam_1:0',
#  'conv2/conv/kernel/Adam:0',
#  'conv2/conv/kernel/Adam_1:0',
#  'conv2/conv/bias/Adam:0',
#  'conv2/conv/bias/Adam_1:0',
#  'conv2/bn/beta/Adam:0',
#  'conv2/bn/beta/Adam_1:0',
#  'conv2/bn/gamma/Adam:0',
#  'conv2/bn/gamma/Adam_1:0',
#  'conv3/conv/kernel/Adam:0',
#  'conv3/conv/kernel/Adam_1:0',
#  'conv3/conv/bias/Adam:0',
#  'conv3/conv/bias/Adam_1:0',
#  'conv3/bn/beta/Adam:0',
#  'conv3/bn/beta/Adam_1:0',
#  'conv3/bn/gamma/Adam:0',
#  'conv3/bn/gamma/Adam_1:0',
#  'conv4/conv/kernel/Adam:0',
#  'conv4/conv/kernel/Adam_1:0',
#  'conv4/conv/bias/Adam:0',
#  'conv4/conv/bias/Adam_1:0',
#  'conv4/bn/beta/Adam:0',
#  'conv4/bn/beta/Adam_1:0',
#  'conv4/bn/gamma/Adam:0',
#  'conv4/bn/gamma/Adam_1:0',
#  'fc1/dense/kernel/Adam:0',
#  'fc1/dense/kernel/Adam_1:0',
#  'fc1/dense/bias/Adam:0',
#  'fc1/dense/bias/Adam_1:0',
#  'fc1/bn/beta/Adam:0',
#  'fc1/bn/beta/Adam_1:0',
#  'fc1/bn/gamma/Adam:0',
#  'fc1/bn/gamma/Adam_1:0',
#  'fc2/dense/kernel/Adam:0',
#  'fc2/dense/kernel/Adam_1:0',
#  'fc2/dense/bias/Adam:0',
#  'fc2/dense/bias/Adam_1:0',
#  'fc2/bn/beta/Adam:0',
#  'fc2/bn/beta/Adam_1:0',
#  'fc2/bn/gamma/Adam:0',
#  'fc2/bn/gamma/Adam_1:0',
#  'logits/kernel/Adam:0',
#  'logits/kernel/Adam_1:0',
#  'logits/bias/Adam:0',
#  'logits/bias/Adam_1:0']

# %% [markdown]
# All trainable variables

# %%
[v.name for v in tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES)]
# Out:
# ['conv1/conv/kernel:0',
#  'conv1/conv/bias:0',
#  'conv1/bn/beta:0',
#  'conv1/bn/gamma:0',
#  'conv2/conv/kernel:0',
#  'conv2/conv/bias:0',
#  'conv2/bn/beta:0',
#  'conv2/bn/gamma:0',
#  'conv3/conv/kernel:0',
#  'conv3/conv/bias:0',
#  'conv3/bn/beta:0',
#  'conv3/bn/gamma:0',
#  'conv4/conv/kernel:0',
#  'conv4/conv/bias:0',
#  'conv4/bn/beta:0',
#  'conv4/bn/gamma:0',
#  'fc1/dense/kernel:0',
#  'fc1/dense/bias:0',
#  'fc1/bn/beta:0',
#  'fc1/bn/gamma:0',
#  'fc2/dense/kernel:0',
#  'fc2/dense/bias:0',
#  'fc2/bn/beta:0',
#  'fc2/bn/gamma:0',
#  'logits/kernel:0',
#  'logits/bias:0']

# %% [markdown]
# Show regularization parameters

# %%
[v.name for v in tf.get_collection(tf.GraphKeys.REGULARIZATION_LOSSES)]
# Out:
# ['conv1/conv/kernel/Regularizer/l1_regularizer:0',
#  'conv2/conv/kernel/Regularizer/l1_regularizer:0',
#  'conv3/conv/kernel/Regularizer/l1_regularizer:0',
#  'conv4/conv/kernel/Regularizer/l1_regularizer:0',
#  'fc1/dense/kernel/Regularizer/l1_regularizer:0',
#  'fc2/dense/kernel/Regularizer/l1_regularizer:0',
#  'logits/kernel/Regularizer/l1_regularizer:0']

# %% [markdown]
# #### build saver to save the variables of neural network

# %%
saver = tf.train.Saver()
save_dir = 'checkpoints/cifar10'
if not os.path.exists(save_dir): os.makedirs(save_dir)
save_path = os.path.join(save_dir, 'best_validation')

# %% [markdown]
# #### create tensorflow session

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

# %% [markdown]
# #### function to create random mini-batch for training

# %%
train_batch_size = 64
def random_batch(images, labels):
    num_images = len(images)
    idx = np.random.choice(num_images, size=train_batch_size, replace=False)
    x_batch = images[idx,:,:,:]
    y_batch = labels[idx]
    return x_batch, y_batch

# %% [markdown]
# ### Optimizing with early stopping
#
# the classification accuracy for the validation set will be calculated for every `print_every` iterations. The optimization will stop if the validation accuracy has not been improved in `require_improvement` iterations

# %%
best_val_acc = 0
last_improvement = 0
require_improvement = 10000

def optimize(num_iterations):
    global best_val_acc
    global last_improvement

    start_time = time.time()
    for i in range(num_iterations):
        # get batch for training
        x_batch, y_true_batch = random_batch(X_train, y_train)
        feed_dict_train = {x_image: x_batch, y_true_cls: y_true_batch, phase: 1}
        _, lr = sess.run([optimizer, learning_rate], feed_dict=feed_dict_train)
        # print status
        if i % print_every == 0 or i == num_iterations - 1:
            # train accuracy
            acc_train = sess.run(accuracy, feed_dict=feed_dict_train)
            # validation accuracy
            _, correct_val = infer_cls(images=X_val, labels=y_val)
            acc_val = np.mean(correct_val)
            # check if improve over the saved best
            if acc_val > best_val_acc:
                best_val_acc = acc_val
                last_improvement = i
                # save tensorflow variables to file
                saver.save(sess=sess, save_path=save_path)
                improved_str = '*'
            else:
                improved_str = ''
            # status message for printing.
            msg = "Iter: {0:>6}, Learning Rate: {1:>.4E}, Train-Batch Acc: {2:>6.1%}, Val Acc: {3:>6.1%} {4}"
            print(msg.format(i + 1, lr, acc_train, acc_val, improved_str))
        if i - last_improvement > require_improvement:
            print("No improvement found in a while, stopping optimization.")
            break

    end_time = time.time()
    time_delta = end_time - start_time
    print("Time usage: " + str(timedelta(seconds=int(round(time_delta)))))

# %% [markdown]
# Custom function for calculating prediction performance.

# %%
infer_batch_size = 256
def infer_cls(images, labels):
    num_images = len(images)
    cls_pred = np.zeros(num_images, dtype=np.int)
    i = 0
    while i < num_images:
        j = min(i+infer_batch_size, num_images)
        feed_dict = {x_image: images[i:j, :], y_true_cls: labels[i:j], phase: 1}
        cls_pred[i:j] = sess.run(y_pred_cls, feed_dict=feed_dict)
        i = j
    correct = (labels == cls_pred)
    return cls_pred, correct

# %% [markdown]
# Predict for test set and return prediction accuracy.

# %%
def print_test_accuracy():
    _, correct_test = infer_cls(images=X_test, labels=y_test)
    acc_test = np.mean(correct_test)
    num_correct_test = np.sum(correct_test)
    num_test_images = len(X_test)
    # Print the accuracy.
    msg = "Accuracy on Test-Set: {0:.1%} ({1} / {2})"
    print(msg.format(acc_test, num_correct_test, num_test_images))

# %% [markdown]
# #### Run predefined functions and tensorflow graphs

# %% [markdown]
# Check for performance after 100000 iterations.

# %%
optimize(num_iterations=100000)
print_test_accuracy()
# Out:
# Iter:      1, Learning Rate: 1.0000E-03, Train-Batch Acc:  84.4%, Val Acc:  17.8% *
# Iter:   1001, Learning Rate: 9.5000E-04, Train-Batch Acc:  81.2%, Val Acc:  64.8% *
# Iter:   2001, Learning Rate: 9.0250E-04, Train-Batch Acc:  73.4%, Val Acc:  69.0% *
# Iter:   3001, Learning Rate: 8.5737E-04, Train-Batch Acc:  73.4%, Val Acc:  73.1% *
# Iter:   4001, Learning Rate: 8.1451E-04, Train-Batch Acc:  87.5%, Val Acc:  73.4% *
# Iter:   5001, Learning Rate: 7.7378E-04, Train-Batch Acc:  76.6%, Val Acc:  73.9% *
# Iter:   6001, Learning Rate: 7.3509E-04, Train-Batch Acc:  79.7%, Val Acc:  74.8% *
# Iter:   7001, Learning Rate: 6.9834E-04, Train-Batch Acc:  79.7%, Val Acc:  74.4%
# Iter:   8001, Learning Rate: 6.6342E-04, Train-Batch Acc:  84.4%, Val Acc:  75.1% *
# Iter:   9001, Learning Rate: 6.3025E-04, Train-Batch Acc:  89.1%, Val Acc:  75.2% *
# Iter:  10001, Learning Rate: 5.9874E-04, Train-Batch Acc:  81.2%, Val Acc:  76.9% *
# Iter:  11001, Learning Rate: 5.6880E-04, Train-Batch Acc:  85.9%, Val Acc:  77.1% *
# Iter:  12001, Learning Rate: 5.4036E-04, Train-Batch Acc:  89.1%, Val Acc:  76.5%
# Iter:  13001, Learning Rate: 5.1334E-04, Train-Batch Acc:  89.1%, Val Acc:  76.9%
# Iter:  14001, Learning Rate: 4.8767E-04, Train-Batch Acc:  92.2%, Val Acc:  77.2% *
# Iter:  15001, Learning Rate: 4.6329E-04, Train-Batch Acc:  89.1%, Val Acc:  77.2% *
# Iter:  16001, Learning Rate: 4.4013E-04, Train-Batch Acc:  90.6%, Val Acc:  76.6%
# Iter:  17001, Learning Rate: 4.1812E-04, Train-Batch Acc:  92.2%, Val Acc:  78.0% *
# Iter:  18001, Learning Rate: 3.9721E-04, Train-Batch Acc:  96.9%, Val Acc:  77.2%
# Iter:  19001, Learning Rate: 3.7735E-04, Train-Batch Acc:  95.3%, Val Acc:  75.9%
# Iter:  20001, Learning Rate: 3.5849E-04, Train-Batch Acc:  90.6%, Val Acc:  78.0%
# Iter:  21001, Learning Rate: 3.4056E-04, Train-Batch Acc:  84.4%, Val Acc:  77.1%
# Iter:  22001, Learning Rate: 3.2353E-04, Train-Batch Acc:  92.2%, Val Acc:  76.6%
# Iter:  23001, Learning Rate: 3.0736E-04, Train-Batch Acc:  95.3%, Val Acc:  76.4%
# Iter:  24001, Learning Rate: 2.9199E-04, Train-Batch Acc:  92.2%, Val Acc:  77.8%
# Iter:  25001, Learning Rate: 2.7739E-04, Train-Batch Acc:  90.6%, Val Acc:  76.8%
# Iter:  26001, Learning Rate: 2.6352E-04, Train-Batch Acc:  93.8%, Val Acc:  77.3%
# Iter:  27001, Learning Rate: 2.5034E-04, Train-Batch Acc:  90.6%, Val Acc:  76.7%
# No improvement found in a while, stopping optimization.
# Time usage: 0:12:14
# Accuracy on Test-Set: 75.9% (7594 / 10000)

# %% [markdown]
# Restore best variables and model, print test accuracy.

# %%
sess.run(tf.global_variables_initializer())
saver.restore(sess=sess, save_path=save_path)
print_test_accuracy()
# Out:
# Accuracy on Test-Set: 76.4% (7641 / 10000)

# %% [markdown]
# ### Conclusion
#
# - It turns out with reg=0.05, the cnn starts to overfit for the train and the final validation accuracy is 78.7%, the final test accuracy is 77.0% for the best model.
# - With reg=0.1, there's less overfitting, but the prediction accurary improves only a little bit. The test accuracy improves to 77.4% in this case. while the validation accuracy stays the same.
# - With l1 regularization, test accuracy is 76.2% for reg=1e-3
